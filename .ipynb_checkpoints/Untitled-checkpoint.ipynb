# %%
import pandas as pd
from tkinter import *
import tkinter as tk
import tkinter.font as tkFont
from tkinter import filedialog, messagebox, ttk
from datetime import timedelta, datetime

jobs_test = [["Job 1-4", 4], ["Job 2-2", 2], ["Job 3-2", 2],["Job 4-8", 8], ["Job 5-2", 2]]

machines_list = ["XYZ", "TM-6", "TM8-2", "TM8-1", "VMX-30", "VMX-30-4", "VM-10", "VM10-2", "VMC-2", "VMC-1"]
days_list = [["Monday", 8], ["Tuesday", 8], ["Wednesday", 8], ["Thursday", 8],
                 ["Friday", 5], ["Saturday", 5], ["Sunday", 5]]

start_date = datetime.today() + timedelta(days=2)

class Slot():
    def __init__(self, avail_hours):
        self.avail_hours = avail_hours
        self.job = "{}H".format(self.avail_hours)




def create_week(machines_list, days_list, start_date):
    # create blank dataframe from days_list * slot numbers
    day_headers_list = []
    for day in days_list:
        day_headers_list.append(day[0])
    print("Created day header list: {}".format(day_headers_list))
    
    date_headers = []
    date = start_date
    for day in days_list:
        date_headers.append(date.strftime("%d %b %y"))
        date = date + timedelta(days=1)
    print("Created date header list: {}".format(date_headers))
   
    df_slots = pd.DataFrame(columns=day_headers_list)  # CREATE DATAFRAME AND ADD HEADERS
    df_slots.loc[0] = day_headers_list
    df_slots.loc[1] = date_headers

    for row in range(0, len(machines_list)):  # FOR EVERY MACHINE ROW...
        rows = []
        for day in days_list:
            #for col in range(0, len(day_headers_list)):   # FOR EVERY COLUMN ADD A "0"
            slot = Slot(day[1])
            rows.append(slot)
        df_length = len(df_slots)  # STORE LENGTH OF DATAFRAME IN df_length
        df_slots.loc[df_length] = rows  # ADD rows LIST CONTENTS TO EACH NEW DATAFRAME ROW

    machines_list.insert(0, "Date")
    machines_list.insert(0, "Day")
    #print("Machine list after insert: {}".format(df_cols_list))

    df_slots['Machines'] = machines_list  # ADD COLUMN WITH MACHINE NAMES
    df_slots = df_slots.set_index('Machines')
    # MAKE THE MACHINES COLUMN THE INDEX ROW
    # (TO ALLOW CALLING SPECIFIC ROW VIA MACHINE NAME

    # slots_final_list = df_slots.values.tolist()
    
    return df_slots

schedule_df = create_week(machines_list, days_list, start_date)
schedule_df
# Out:
# Created day header list: ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# Created date header list: ['15 Mar 21', '16 Mar 21', '17 Mar 21', '18 Mar 21', '19 Mar 21', '20 Mar 21', '21 Mar 21']
#                                                 Monday  \
# Machines
# Day                                             Monday
# Date                                         15 Mar 21
# XYZ       <__main__.Slot object at 0x000002A31079A370>
# TM-6      <__main__.Slot object at 0x000002A3000B98E0>
# TM8-2     <__main__.Slot object at 0x000002A31079A910>
# TM8-1     <__main__.Slot object at 0x000002A31079AD90>
# VMX-30    <__main__.Slot object at 0x000002A310810790>
# VMX-30-4  <__main__.Slot object at 0x000002A310810E20>
# VM-10     <__main__.Slot object at 0x000002A3000B92E0>
# VM10-2    <__main__.Slot object at 0x000002A3108105B0>
# VMC-2     <__main__.Slot object at 0x000002A310820400>
# VMC-1     <__main__.Slot object at 0x000002A3108206D0>
#
#                                                Tuesday  \
# Machines
# Day                                            Tuesday
# Date                                         16 Mar 21
# XYZ       <__main__.Slot object at 0x000002A31079A7C0>
# TM-6      <__main__.Slot object at 0x000002A31079A610>
# TM8-2     <__main__.Slot object at 0x000002A31079A340>
# TM8-1     <__main__.Slot object at 0x000002A31079AB50>
# VMX-30    <__main__.Slot object at 0x000002A310810190>
# VMX-30-4  <__main__.Slot object at 0x000002A3108109A0>
# VM-10     <__main__.Slot object at 0x000002A37FFCACA0>
# VM10-2    <__main__.Slot object at 0x000002A310810A00>
# VMC-2     <__main__.Slot object at 0x000002A310820C40>
# VMC-1     <__main__.Slot object at 0x000002A310820130>
#
#                                              Wednesday  \
# Machines
# Day                                          Wednesday
# Date                                         17 Mar 21
# XYZ       <__main__.Slot object at 0x000002A31079A5B0>
# TM-6      <__main__.Slot object at 0x000002A31079A490>
# TM8-2     <__main__.Slot object at 0x000002A31079AF40>
# TM8-1     <__main__.Slot object at 0x000002A31079A310>
# VMX-30    <__main__.Slot object at 0x000002A3108100D0>
# VMX-30-4  <__main__.Slot object at 0x000002A310810C40>
# VM-10     <__main__.Slot object at 0x000002A310810EB0>
# VM10-2    <__main__.Slot object at 0x000002A310810EE0>
# VMC-2     <__main__.Slot object at 0x000002A3108202B0>
# VMC-1     <__main__.Slot object at 0x000002A3108200D0>
#
#                                               Thursday  \
# Machines
# Day                                           Thursday
# Date                                         18 Mar 21
# XYZ       <__main__.Slot object at 0x000002A31079A790>
# TM-6      <__main__.Slot object at 0x000002A31079AF70>
# TM8-2     <__main__.Slot object at 0x000002A31079AA30>
# TM8-1     <__main__.Slot object at 0x000002A31079A7F0>
# VMX-30    <__main__.Slot object at 0x000002A310810AC0>
# VMX-30-4  <__main__.Slot object at 0x000002A310810970>
# VM-10     <__main__.Slot object at 0x000002A310810FA0>
# VM10-2    <__main__.Slot object at 0x000002A310810C10>
# VMC-2     <__main__.Slot object at 0x000002A310820370>
# VMC-1     <__main__.Slot object at 0x000002A3108203D0>
#
#                                                 Friday  \
# Machines
# Day                                             Friday
# Date                                         19 Mar 21
# XYZ       <__main__.Slot object at 0x000002A31079A130>
# TM-6      <__main__.Slot object at 0x000002A31079ABE0>
# TM8-2     <__main__.Slot object at 0x000002A31079A4C0>
# TM8-1     <__main__.Slot object at 0x000002A31079AE50>
# VMX-30    <__main__.Slot object at 0x000002A310810F40>
# VMX-30-4  <__main__.Slot object at 0x000002A310810310>
# VM-10     <__main__.Slot object at 0x000002A310810B20>
# VM10-2    <__main__.Slot object at 0x000002A310810BE0>
# VMC-2     <__main__.Slot object at 0x000002A310820D60>
# VMC-1     <__main__.Slot object at 0x000002A310820730>
#
#                                               Saturday  \
# Machines
# Day                                           Saturday
# Date                                         20 Mar 21
# XYZ       <__main__.Slot object at 0x000002A31079A520>
# TM-6      <__main__.Slot object at 0x000002A31079A5E0>
# TM8-2     <__main__.Slot object at 0x000002A31079A190>
# TM8-1     <__main__.Slot object at 0x000002A310810F10>
# VMX-30    <__main__.Slot object at 0x000002A3108107C0>
# VMX-30-4  <__main__.Slot object at 0x000002A3108106D0>
# VM-10     <__main__.Slot object at 0x000002A310810DC0>
# VM10-2    <__main__.Slot object at 0x000002A310810880>
# VMC-2     <__main__.Slot object at 0x000002A310820B50>
# VMC-1     <__main__.Slot object at 0x000002A310820760>
#
#                                                 Sunday
# Machines
# Day                                             Sunday
# Date                                         21 Mar 21
# XYZ       <__main__.Slot object at 0x000002A31079AA60>
# TM-6      <__main__.Slot object at 0x000002A31079A160>
# TM8-2     <__main__.Slot object at 0x000002A31079A850>
# TM8-1     <__main__.Slot object at 0x000002A310810760>
# VMX-30    <__main__.Slot object at 0x000002A310810BB0>
# VMX-30-4  <__main__.Slot object at 0x000002A310810CD0>
# VM-10     <__main__.Slot object at 0x000002A310810D30>
# VM10-2    <__main__.Slot object at 0x000002A310820E20>
# VMC-2     <__main__.Slot object at 0x000002A3108201F0>
# VMC-1     <__main__.Slot object at 0x000002A310820850>

# %%
schedule_df['Monday']['XYZ'].job
# Out:
# '8H'

# %%
jobs_list= []
for machine in machines_list[2:]:
    day_jobs_list = []
    for day in days_list:
        #print("Current day: {}, current machine: {}".format(day[0], machine))
        day_jobs_list.append(schedule_df[day[0]][machine].job)
    #print("Day done: {}".format(day_jobs_list))
    jobs_list.append(day_jobs_list)
jobs_list
# Out:
# [['8H', '8H', '8H', '8H', '5H', '5H', '5H'],
#  ['8H', '8H', '8H', '8H', '5H', '5H', '5H'],
#  ['8H', '8H', '8H', '8H', '5H', '5H', '5H'],
#  ['8H', '8H', '8H', '8H', '5H', '5H', '5H'],
#  ['8H', '8H', '8H', '8H', '5H', '5H', '5H'],
#  ['8H', '8H', '8H', '8H', '5H', '5H', '5H'],
#  ['8H', '8H', '8H', '8H', '5H', '5H', '5H'],
#  ['8H', '8H', '8H', '8H', '5H', '5H', '5H'],
#  ['8H', '8H', '8H', '8H', '5H', '5H', '5H'],
#  ['8H', '8H', '8H', '8H', '5H', '5H', '5H']]

# %%
new_df = schedule_df
list_row_ref = 0
for machine in machines_list[2:]:
    day_jobs_list = []
    list_col_ref=0
    for day in days_list:
        print("row {}, column {}, value: {}".format(list_row_ref, list_col_ref, jobs_list[list_row_ref][list_col_ref]))
        print("DF value: {}".format(new_df[day[0]][machine]))
        new_df.at[machine, day[0]] = jobs_list[list_row_ref][list_col_ref]
        print("New df value = {} ".format(new_df[day[0]][machine]))
        list_col_ref += 1
    list_row_ref += 1
    #print("Day done: {}".format(day_jobs_list))
    
new_df
# Out:
# row 0, column 0, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079A370>
# New df value = <__main__.Slot object at 0x000002A31079A370>
# row 0, column 1, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079A7C0>
# New df value = <__main__.Slot object at 0x000002A31079A7C0>
# row 0, column 2, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079A5B0>
# New df value = <__main__.Slot object at 0x000002A31079A5B0>
# row 0, column 3, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079A790>
# New df value = <__main__.Slot object at 0x000002A31079A790>
# row 0, column 4, value: 5H
# DF value: <__main__.Slot object at 0x000002A31079A130>
# New df value = <__main__.Slot object at 0x000002A31079A130>
# row 0, column 5, value: 5H
# DF value: <__main__.Slot object at 0x000002A31079A520>
# New df value = <__main__.Slot object at 0x000002A31079A520>
# row 0, column 6, value: 5H
# DF value: <__main__.Slot object at 0x000002A31079AA60>
# New df value = <__main__.Slot object at 0x000002A31079AA60>
# row 1, column 0, value: 8H
# DF value: <__main__.Slot object at 0x000002A3000B98E0>
# New df value = <__main__.Slot object at 0x000002A3000B98E0>
# row 1, column 1, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079A610>
# New df value = <__main__.Slot object at 0x000002A31079A610>
# row 1, column 2, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079A490>
# New df value = <__main__.Slot object at 0x000002A31079A490>
# row 1, column 3, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079AF70>
# New df value = <__main__.Slot object at 0x000002A31079AF70>
# row 1, column 4, value: 5H
# DF value: <__main__.Slot object at 0x000002A31079ABE0>
# New df value = <__main__.Slot object at 0x000002A31079ABE0>
# row 1, column 5, value: 5H
# DF value: <__main__.Slot object at 0x000002A31079A5E0>
# New df value = <__main__.Slot object at 0x000002A31079A5E0>
# row 1, column 6, value: 5H
# DF value: <__main__.Slot object at 0x000002A31079A160>
# New df value = <__main__.Slot object at 0x000002A31079A160>
# row 2, column 0, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079A910>
# New df value = <__main__.Slot object at 0x000002A31079A910>
# row 2, column 1, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079A340>
# New df value = <__main__.Slot object at 0x000002A31079A340>
# row 2, column 2, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079AF40>
# New df value = <__main__.Slot object at 0x000002A31079AF40>
# row 2, column 3, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079AA30>
# New df value = <__main__.Slot object at 0x000002A31079AA30>
# row 2, column 4, value: 5H
# DF value: <__main__.Slot object at 0x000002A31079A4C0>
# New df value = <__main__.Slot object at 0x000002A31079A4C0>
# row 2, column 5, value: 5H
# DF value: <__main__.Slot object at 0x000002A31079A190>
# New df value = <__main__.Slot object at 0x000002A31079A190>
# row 2, column 6, value: 5H
# DF value: <__main__.Slot object at 0x000002A31079A850>
# New df value = <__main__.Slot object at 0x000002A31079A850>
# row 3, column 0, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079AD90>
# New df value = <__main__.Slot object at 0x000002A31079AD90>
# row 3, column 1, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079AB50>
# New df value = <__main__.Slot object at 0x000002A31079AB50>
# row 3, column 2, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079A310>
# New df value = <__main__.Slot object at 0x000002A31079A310>
# row 3, column 3, value: 8H
# DF value: <__main__.Slot object at 0x000002A31079A7F0>
# New df value = <__main__.Slot object at 0x000002A31079A7F0>
# row 3, column 4, value: 5H
# DF value: <__main__.Slot object at 0x000002A31079AE50>
# New df value = <__main__.Slot object at 0x000002A31079AE50>
# row 3, column 5, value: 5H
# DF value: <__main__.Slot object at 0x000002A310810F10>
# New df value = <__main__.Slot object at 0x000002A310810F10>
# row 3, column 6, value: 5H
# DF value: <__main__.Slot object at 0x000002A310810760>
# New df value = <__main__.Slot object at 0x000002A310810760>
# row 4, column 0, value: 8H
# DF value: <__main__.Slot object at 0x000002A310810790>
# New df value = <__main__.Slot object at 0x000002A310810790>
# row 4, column 1, value: 8H
# DF value: <__main__.Slot object at 0x000002A310810190>
# New df value = <__main__.Slot object at 0x000002A310810190>
# row 4, column 2, value: 8H
# DF value: <__main__.Slot object at 0x000002A3108100D0>
# New df value = <__main__.Slot object at 0x000002A3108100D0>
# row 4, column 3, value: 8H
# DF value: <__main__.Slot object at 0x000002A310810AC0>
# New df value = <__main__.Slot object at 0x000002A310810AC0>
# row 4, column 4, value: 5H
# DF value: <__main__.Slot object at 0x000002A310810F40>
# New df value = <__main__.Slot object at 0x000002A310810F40>
# row 4, column 5, value: 5H
# DF value: <__main__.Slot object at 0x000002A3108107C0>
# New df value = <__main__.Slot object at 0x000002A3108107C0>
# row 4, column 6, value: 5H
# DF value: <__main__.Slot object at 0x000002A310810BB0>
# New df value = <__main__.Slot object at 0x000002A310810BB0>
# row 5, column 0, value: 8H
# DF value: <__main__.Slot object at 0x000002A310810E20>
# New df value = <__main__.Slot object at 0x000002A310810E20>
# row 5, column 1, value: 8H
# DF value: <__main__.Slot object at 0x000002A3108109A0>
# New df value = <__main__.Slot object at 0x000002A3108109A0>
# row 5, column 2, value: 8H
# DF value: <__main__.Slot object at 0x000002A310810C40>
# New df value = <__main__.Slot object at 0x000002A310810C40>
# row 5, column 3, value: 8H
# DF value: <__main__.Slot object at 0x000002A310810970>
# New df value = <__main__.Slot object at 0x000002A310810970>
# row 5, column 4, value: 5H
# DF value: <__main__.Slot object at 0x000002A310810310>
# New df value = <__main__.Slot object at 0x000002A310810310>
# row 5, column 5, value: 5H
# DF value: <__main__.Slot object at 0x000002A3108106D0>
# New df value = <__main__.Slot object at 0x000002A3108106D0>
# row 5, column 6, value: 5H
# DF value: <__main__.Slot object at 0x000002A310810CD0>
# New df value = <__main__.Slot object at 0x000002A310810CD0>
# row 6, column 0, value: 8H
# DF value: <__main__.Slot object at 0x000002A3000B92E0>
# New df value = <__main__.Slot object at 0x000002A3000B92E0>
# row 6, column 1, value: 8H
# DF value: <__main__.Slot object at 0x000002A37FFCACA0>
# New df value = <__main__.Slot object at 0x000002A37FFCACA0>
# row 6, column 2, value: 8H
# DF value: <__main__.Slot object at 0x000002A310810EB0>
# New df value = <__main__.Slot object at 0x000002A310810EB0>
# row 6, column 3, value: 8H
# DF value: <__main__.Slot object at 0x000002A310810FA0>
# New df value = <__main__.Slot object at 0x000002A310810FA0>
# row 6, column 4, value: 5H
# DF value: <__main__.Slot object at 0x000002A310810B20>
# New df value = <__main__.Slot object at 0x000002A310810B20>
# row 6, column 5, value: 5H
# DF value: <__main__.Slot object at 0x000002A310810DC0>
# New df value = <__main__.Slot object at 0x000002A310810DC0>
# row 6, column 6, value: 5H
# DF value: <__main__.Slot object at 0x000002A310810D30>
# New df value = <__main__.Slot object at 0x000002A310810D30>
# row 7, column 0, value: 8H
# DF value: <__main__.Slot object at 0x000002A3108105B0>
# New df value = <__main__.Slot object at 0x000002A3108105B0>
# row 7, column 1, value: 8H
# DF value: <__main__.Slot object at 0x000002A310810A00>
# New df value = <__main__.Slot object at 0x000002A310810A00>
# row 7, column 2, value: 8H
# DF value: <__main__.Slot object at 0x000002A310810EE0>
# New df value = <__main__.Slot object at 0x000002A310810EE0>
# row 7, column 3, value: 8H
# DF value: <__main__.Slot object at 0x000002A310810C10>
# New df value = <__main__.Slot object at 0x000002A310810C10>
# row 7, column 4, value: 5H
# DF value: <__main__.Slot object at 0x000002A310810BE0>
# New df value = <__main__.Slot object at 0x000002A310810BE0>
# row 7, column 5, value: 5H
# DF value: <__main__.Slot object at 0x000002A310810880>
# New df value = <__main__.Slot object at 0x000002A310810880>
# row 7, column 6, value: 5H
# DF value: <__main__.Slot object at 0x000002A310820E20>
# New df value = <__main__.Slot object at 0x000002A310820E20>
# row 8, column 0, value: 8H
# DF value: <__main__.Slot object at 0x000002A310820400>
# New df value = <__main__.Slot object at 0x000002A310820400>
# row 8, column 1, value: 8H
# DF value: <__main__.Slot object at 0x000002A310820C40>
# New df value = <__main__.Slot object at 0x000002A310820C40>
# row 8, column 2, value: 8H
# DF value: <__main__.Slot object at 0x000002A3108202B0>
# New df value = <__main__.Slot object at 0x000002A3108202B0>
# row 8, column 3, value: 8H
# DF value: <__main__.Slot object at 0x000002A310820370>
# New df value = <__main__.Slot object at 0x000002A310820370>
# row 8, column 4, value: 5H
# DF value: <__main__.Slot object at 0x000002A310820D60>
# New df value = <__main__.Slot object at 0x000002A310820D60>
# row 8, column 5, value: 5H
# DF value: <__main__.Slot object at 0x000002A310820B50>
# New df value = <__main__.Slot object at 0x000002A310820B50>
# row 8, column 6, value: 5H
# DF value: <__main__.Slot object at 0x000002A3108201F0>
# New df value = <__main__.Slot object at 0x000002A3108201F0>
# row 9, column 0, value: 8H
# DF value: <__main__.Slot object at 0x000002A3108206D0>
# New df value = <__main__.Slot object at 0x000002A3108206D0>
# row 9, column 1, value: 8H
# DF value: <__main__.Slot object at 0x000002A310820130>
# New df value = <__main__.Slot object at 0x000002A310820130>
# row 9, column 2, value: 8H
# DF value: <__main__.Slot object at 0x000002A3108200D0>
# New df value = <__main__.Slot object at 0x000002A3108200D0>
# row 9, column 3, value: 8H
# DF value: <__main__.Slot object at 0x000002A3108203D0>
# New df value = <__main__.Slot object at 0x000002A3108203D0>
# row 9, column 4, value: 5H
# DF value: <__main__.Slot object at 0x000002A310820730>
# New df value = <__main__.Slot object at 0x000002A310820730>
# row 9, column 5, value: 5H
# DF value: <__main__.Slot object at 0x000002A310820760>
# New df value = <__main__.Slot object at 0x000002A310820760>
# row 9, column 6, value: 5H
# DF value: <__main__.Slot object at 0x000002A310820850>
# New df value = <__main__.Slot object at 0x000002A310820850>
#                                                  Monday  \
# Machines
# Day                                              Monday
# Date                                          15 Mar 21
# XYZ        <__main__.Slot object at 0x000002A31079A370>
# TM-6       <__main__.Slot object at 0x000002A3000B98E0>
# TM8-2      <__main__.Slot object at 0x000002A31079A910>
# TM8-1      <__main__.Slot object at 0x000002A31079AD90>
# VMX-30     <__main__.Slot object at 0x000002A310810790>
# VMX-30-4   <__main__.Slot object at 0x000002A310810E20>
# VM-10      <__main__.Slot object at 0x000002A3000B92E0>
# VM10-2     <__main__.Slot object at 0x000002A3108105B0>
# VMC-2      <__main__.Slot object at 0x000002A310820400>
# VMC-1      <__main__.Slot object at 0x000002A3108206D0>
# Monday                                              NaN
# Tuesday                                             NaN
# Wednesday                                           NaN
# Thursday                                            NaN
# Friday                                              NaN
# Saturday                                            NaN
# Sunday                                              NaN
#
#                                                 Tuesday  \
# Machines
# Day                                             Tuesday
# Date                                          16 Mar 21
# XYZ        <__main__.Slot object at 0x000002A31079A7C0>
# TM-6       <__main__.Slot object at 0x000002A31079A610>
# TM8-2      <__main__.Slot object at 0x000002A31079A340>
# TM8-1      <__main__.Slot object at 0x000002A31079AB50>
# VMX-30     <__main__.Slot object at 0x000002A310810190>
# VMX-30-4   <__main__.Slot object at 0x000002A3108109A0>
# VM-10      <__main__.Slot object at 0x000002A37FFCACA0>
# VM10-2     <__main__.Slot object at 0x000002A310810A00>
# VMC-2      <__main__.Slot object at 0x000002A310820C40>
# VMC-1      <__main__.Slot object at 0x000002A310820130>
# Monday                                              NaN
# Tuesday                                             NaN
# Wednesday                                           NaN
# Thursday                                            NaN
# Friday                                              NaN
# Saturday                                            NaN
# Sunday                                              NaN
#
#                                               Wednesday  \
# Machines
# Day                                           Wednesday
# Date                                          17 Mar 21
# XYZ        <__main__.Slot object at 0x000002A31079A5B0>
# TM-6       <__main__.Slot object at 0x000002A31079A490>
# TM8-2      <__main__.Slot object at 0x000002A31079AF40>
# TM8-1      <__main__.Slot object at 0x000002A31079A310>
# VMX-30     <__main__.Slot object at 0x000002A3108100D0>
# VMX-30-4   <__main__.Slot object at 0x000002A310810C40>
# VM-10      <__main__.Slot object at 0x000002A310810EB0>
# VM10-2     <__main__.Slot object at 0x000002A310810EE0>
# VMC-2      <__main__.Slot object at 0x000002A3108202B0>
# VMC-1      <__main__.Slot object at 0x000002A3108200D0>
# Monday                                              NaN
# Tuesday                                             NaN
# Wednesday                                           NaN
# Thursday                                            NaN
# Friday                                              NaN
# Saturday                                            NaN
# Sunday                                              NaN
#
#                                                Thursday  \
# Machines
# Day                                            Thursday
# Date                                          18 Mar 21
# XYZ        <__main__.Slot object at 0x000002A31079A790>
# TM-6       <__main__.Slot object at 0x000002A31079AF70>
# TM8-2      <__main__.Slot object at 0x000002A31079AA30>
# TM8-1      <__main__.Slot object at 0x000002A31079A7F0>
# VMX-30     <__main__.Slot object at 0x000002A310810AC0>
# VMX-30-4   <__main__.Slot object at 0x000002A310810970>
# VM-10      <__main__.Slot object at 0x000002A310810FA0>
# VM10-2     <__main__.Slot object at 0x000002A310810C10>
# VMC-2      <__main__.Slot object at 0x000002A310820370>
# VMC-1      <__main__.Slot object at 0x000002A3108203D0>
# Monday                                              NaN
# Tuesday                                             NaN
# Wednesday                                           NaN
# Thursday                                            NaN
# Friday                                              NaN
# Saturday                                            NaN
# Sunday                                              NaN
#
#                                                  Friday  \
# Machines
# Day                                              Friday
# Date                                          19 Mar 21
# XYZ        <__main__.Slot object at 0x000002A31079A130>
# TM-6       <__main__.Slot object at 0x000002A31079ABE0>
# TM8-2      <__main__.Slot object at 0x000002A31079A4C0>
# TM8-1      <__main__.Slot object at 0x000002A31079AE50>
# VMX-30     <__main__.Slot object at 0x000002A310810F40>
# VMX-30-4   <__main__.Slot object at 0x000002A310810310>
# VM-10      <__main__.Slot object at 0x000002A310810B20>
# VM10-2     <__main__.Slot object at 0x000002A310810BE0>
# VMC-2      <__main__.Slot object at 0x000002A310820D60>
# VMC-1      <__main__.Slot object at 0x000002A310820730>
# Monday                                              NaN
# Tuesday                                             NaN
# Wednesday                                           NaN
# Thursday                                            NaN
# Friday                                              NaN
# Saturday                                            NaN
# Sunday                                              NaN
#
#                                                Saturday  \
# Machines
# Day                                            Saturday
# Date                                          20 Mar 21
# XYZ        <__main__.Slot object at 0x000002A31079A520>
# TM-6       <__main__.Slot object at 0x000002A31079A5E0>
# TM8-2      <__main__.Slot object at 0x000002A31079A190>
# TM8-1      <__main__.Slot object at 0x000002A310810F10>
# VMX-30     <__main__.Slot object at 0x000002A3108107C0>
# VMX-30-4   <__main__.Slot object at 0x000002A3108106D0>
# VM-10      <__main__.Slot object at 0x000002A310810DC0>
# VM10-2     <__main__.Slot object at 0x000002A310810880>
# VMC-2      <__main__.Slot object at 0x000002A310820B50>
# VMC-1      <__main__.Slot object at 0x000002A310820760>
# Monday                                              NaN
# Tuesday                                             NaN
# Wednesday                                           NaN
# Thursday                                            NaN
# Friday                                              NaN
# Saturday                                            NaN
# Sunday                                              NaN
#
#                                                  Sunday  XYZ TM-6 TM8-2 TM8-1  \
# Machines
# Day                                              Sunday  NaN  NaN   NaN   NaN
# Date                                          21 Mar 21  NaN  NaN   NaN   NaN
# XYZ        <__main__.Slot object at 0x000002A31079AA60>  NaN  NaN   NaN   NaN
# TM-6       <__main__.Slot object at 0x000002A31079A160>  NaN  NaN   NaN   NaN
# TM8-2      <__main__.Slot object at 0x000002A31079A850>  NaN  NaN   NaN   NaN
# TM8-1      <__main__.Slot object at 0x000002A310810760>  NaN  NaN   NaN   NaN
# VMX-30     <__main__.Slot object at 0x000002A310810BB0>  NaN  NaN   NaN   NaN
# VMX-30-4   <__main__.Slot object at 0x000002A310810CD0>  NaN  NaN   NaN   NaN
# VM-10      <__main__.Slot object at 0x000002A310810D30>  NaN  NaN   NaN   NaN
# VM10-2     <__main__.Slot object at 0x000002A310820E20>  NaN  NaN   NaN   NaN
# VMC-2      <__main__.Slot object at 0x000002A3108201F0>  NaN  NaN   NaN   NaN
# VMC-1      <__main__.Slot object at 0x000002A310820850>  NaN  NaN   NaN   NaN
# Monday                                              NaN    5    5     5     5
# Tuesday                                             NaN    5    5     5     5
# Wednesday                                           NaN    5    5     5     5
# Thursday                                            NaN    5    5     5     5
# Friday                                              NaN    5    5     5     5
# Saturday                                            NaN    5    5     5     5
# Sunday                                              NaN    5    5     5     5
#
#           VMX-30 VMX-30-4 VM-10 VM10-2 VMC-2 VMC-1
# Machines
# Day          NaN      NaN   NaN    NaN   NaN   NaN
# Date         NaN      NaN   NaN    NaN   NaN   NaN
# XYZ          NaN      NaN   NaN    NaN   NaN   NaN
# TM-6         NaN      NaN   NaN    NaN   NaN   NaN
# TM8-2        NaN      NaN   NaN    NaN   NaN   NaN
# TM8-1        NaN      NaN   NaN    NaN   NaN   NaN
# VMX-30       NaN      NaN   NaN    NaN   NaN   NaN
# VMX-30-4     NaN      NaN   NaN    NaN   NaN   NaN
# VM-10        NaN      NaN   NaN    NaN   NaN   NaN
# VM10-2       NaN      NaN   NaN    NaN   NaN   NaN
# VMC-2        NaN      NaN   NaN    NaN   NaN   NaN
# VMC-1        NaN      NaN   NaN    NaN   NaN   NaN
# Monday         5        5     5      5     5     5
# Tuesday        5        5     5      5     5     5
# Wednesday      5        5     5      5     5     5
# Thursday       5        5     5      5     5     5
# Friday         5        5     5      5     5     5
# Saturday       5        5     5      5     5     5
# Sunday         5        5     5      5     5     5
